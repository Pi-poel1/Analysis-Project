# %% [markdown]
# # Accès aux données de l'API OECD

# %% [markdown]
# ### 1.Extraction de données depuis l'API OECD

# %% [markdown]
# Ici, j'ai extrait des données depuis différentes API et je les ai placées dans des fichiers CSV.

# %%
import requests
import pandas as pd

# URL de l'API avec les paramètres fournis
url = 'https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_V,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.B6GS1M_POP..?startPeriod=2000&dimensionAtObservation=AllDimensions&format=csvfilewithlabels'

# Autres URL qui j'ai utiliser

# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_I,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.B1GQ_R_GR..?startPeriod=2000&dimensionAtObservation=AllDimensions&format=csvfilewithlabels
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_II,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.B5N_R_GR..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_III_CG,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.P3S1M_CG..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG_IV@DF_NAAG_IV,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.B1G_GR._T..?startPeriod=2000&dimensionAtObservation=AllDimensions***
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_V,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.B6GS1M_POP..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG_VI@DF_NAAG_EXP,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.OTES13...?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG_VI@DF_NAAG_OTEF,1.0/A.AUS+AUT+BEL+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+NLD+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+GBR+USA.OTES13F._T..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_VII,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.LES11_FD4_B2G..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_VIII,1.0/A.AUS+AUT+BEL+CAN+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+GBR+USA.LE_N11N..?startPeriod=2000&dimensionAtObservation=AllDimensions
# https://sdmx.oecd.org/public/rest/data/OECD.SDD.NAD,DSD_NAAG@DF_NAAG_IX,1.0/A.AUS+AUT+BEL+CAN+CHL+COL+CRI+CZE+DNK+EST+FIN+FRA+DEU+GRC+HUN+ISL+IRL+ISR+ITA+JPN+KOR+LVA+LTU+LUX+MEX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+SWE+CHE+TUR+GBR+USA.EXC_A..?startPeriod=2000&dimensionAtObservation=AllDimensions


# Faire une requête GET pour récupérer les données au format CSV
response = requests.get(url)

# Vérifier si la requête a réussi (code 200)
if response.status_code == 200:
    # Sauvegarder le contenu CSV dans un fichier local
    with open('oecd_data.csv', 'wb') as file:
        file.write(response.content)
    print("Les données ont été téléchargées avec succès sous 'oecd_data.csv'.")
else:
    print(f"Erreur lors de la récupération des données: {response.status_code}")

# Charger les données CSV dans un DataFrame pandas
df = pd.read_csv('oecd_data.csv')

# Afficher les premières lignes du DataFrame pour vérifier les données
print(df.head())

# %% [markdown]
# Ici, j'ai extrait seulement les colonnes nécessaires.

# %%
df_filtred = df[['Reference area', 'OBS_VALUE','TIME_PERIOD']]

# %%
# Renomer le Vlue et placer les valuer dans un fichier csv 
df_filtred.rename(columns={'OBS_VALUE':'Households'}, inplace=True)
df_filtred.to_csv('NAAG5.csv')

# %% [markdown]
# ### 2. Jointure de fichiers pour construire un seul dataset

# %% [markdown]
# Ici, j'ai rassemblé tous les fichiers CSV déjà construits pour obtenir le dataset final

# %%
import pandas as pd
import os

# 1. Définir le dossier courant (où se trouve le script)
chemin_dossier = os.getcwd()

# 2. Récupérer la liste des fichiers CSV contenant 'NAAG' dans leur nom
fichiers_csv = [f for f in os.listdir(chemin_dossier) if f.endswith('.csv') and 'NAAG' in f]

# 3. Initialiser une variable pour le dataset fusionné
dataset_final = None

# %%
# 4. Fusionner les fichiers sur 'ref area' et 'time period'
for fichier in fichiers_csv:
    print(f"Traitement du fichier : {fichier}")
    df = pd.read_csv(fichier)  # Charger le fichier CSV
    
    # Supprimer la colonne 'Unnamed: 0' si elle existe
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])
    
    if dataset_final is None:
        dataset_final = df  # Initialiser le dataset final avec le premier fichier
    else:
        # Fusionner sur 'ref area' et 'time period' avec les nouvelles données
        dataset_final = pd.merge(dataset_final, df, on=['Reference area', 'TIME_PERIOD'], how='outer')

# 5. Afficher les premières lignes du dataset final
print("Aperçu du dataset fusionné :")
print(dataset_final.head())

# 6. Exporter le dataset fusionné dans un nouveau fichier CSV
nom_fichier_sortie = "dataset_final_merge.csv"
dataset_final.to_csv(nom_fichier_sortie, index=False)
print(f"Le fichier fusionné a été sauvegardé sous : {nom_fichier_sortie}")

# %% [markdown]
# ### 3.le nettoyage des données

# %% [markdown]
# Pour cela, j'ai vérifié qu'il y avait certaines valeurs manquantes dans les colonnes, et j'ai utilisé la fonction interpolate pour remplir les valeurs NaN

# %%
import pandas as pd

dataset = pd.read_csv('dataset_final_merge.csv')

# Interpoler les valeurs manquantes (linéaire par défaut)
dataset_interpolated = dataset.interpolate(method='linear', axis=0)

# Vérifier si les valeurs manquantes sont traitées
print("Valeurs manquantes après interpolation :")
print(dataset_interpolated.isnull().sum())

# Sauvegarder le dataset interpolé
output_file_path = 'dataset_interpolated.csv'
dataset_interpolated.to_csv(output_file_path, index=False)
print(f"Le dataset avec interpolation a été sauvegardé sous : {output_file_path}")

# %% [markdown]
# ### 4. Exploration du dataset final

# %%
import pandas as pd
# Chargment de dataset
df = pd.read_csv('dataset_fin.csv')
df.head()
# Out:
#    Unnamed: 0 Reference area       GDP  TIME_PERIOD    Income  Expenditure   \
# 0           0      Australia  3.441992         2022  2.630387      6.318369
# 1           1        Austria  5.277894         2022  0.676556      4.911191
# 2           2        Belgium  4.233432         2022  0.945041      3.635884
# 3           3         Canada  4.189036         2022  5.478162      5.464745
# 4           4          Chile  2.058740         2022 -1.181835      1.642339
#
#    Components of aggregate demand  Production    Households  Government  \
# 0                        3.090439    3.665822  39871.843115   37.198877
# 1                        2.438285    6.070283  40299.683652   53.010387
# 2                        1.815193    4.515443  36499.838230   52.240785
# 3                        2.960486    4.139944  34203.373443   41.238013
# 4                        1.019797    2.282649  16552.007381   27.749244
#
#    Government expenditure by fun  Corporations     Capital  \
# ...

# %% [markdown]
# **Notre dataset contient 49 enregistrements et 13 colonnes:**
#
# * 1.Reference area :
#    La région ou le pays de référence pour les données (ex. Australia, Austria).
# * 2.GDP (Gross Domestic Product) :
#    La valeur totale de tous les biens et services produits dans une économie sur une période donnée.
#    C'est un indicateur clé de la santé économique d'un pays.
# * 3.TIME_PERIOD :
#    L'année ou la période de référence pour les données (ex. 2022).
# * 4.Income :
#    Le revenu total généré par un pays ou une région. Cela peut inclure les revenus des ménages, des entreprises et du gouvernement.
# * 5.Expenditure :
#    Les dépenses totales, incluant les dépenses des ménages, des entreprises, et du gouvernement pour des biens et services.
# * 6.Components of aggregate demand :
#    Les différents éléments de la demande agrégée, tels que la consommation, l'investissement, les dépenses publiques et les exportations nettes.
# * 7.Production :
#    Indicateurs liés à la production, la production totale d'une économie.
# * 8.Households :
#    Indicateurs spécifiques aux ménages, tels que le revenu disponible, l'épargne, ou la richesse nette.
# * 9.Government :
#    Vue d'ensemble des finances publiques, incluant les revenus, les dépenses, la dette ou d'autres indicateurs liés aux actions du gouvernement.
# * 10.Government expenditure by fun :
#    Détail des dépenses publiques par fonction, comme la santé, l'éducation, la défense ou les infrastructures.
# * 11.Corporations :
#    Indicateurs relatifs aux entreprises, incluant les profits, les investissements, ou d'autres mesures de performance économique.
# * 12.Capital :
#    Indicateurs du stock de capital, incluant l'accumulation de biens durables utilisés dans la production (machines, infrastructures), ainsi que l'amortissement ou la dépréciation.
# * 13.Economic_Classification :
#    Une catégorisation des pays selon leur niveau de développement ou leur classification économique, comme "Emerging" (économies émergentes) ou "Developing" (économies en développement).

# %%
# vérifier le nombre de valeurs manquantes (NaN) par colonne
df.isna().sum()
# Out:
# Unnamed: 0                        0
# Reference area                    0
# GDP                               0
# TIME_PERIOD                       0
# Income                            0
# Expenditure                       0
# Components of aggregate demand    0
# Production                        0
# Households                        0
# Government                        0
# Government expenditure by fun     0
# Corporations                      0
# Capital                           0
# Economic_Classification           0
# dtype: int64

# %%
# statistiques descriptives des données numériques
df.describe()
# Out:
#        Unnamed: 0        GDP  TIME_PERIOD     Income  Expenditure   \
# count    49.00000  49.000000         49.0  49.000000     49.000000
# mean     24.00000   3.651922       2022.0   1.714532      4.934749
# std      14.28869   2.173463          0.0   4.962084      3.242230
# min       0.00000   0.060430       2022.0  -5.066352     -2.086819
# 25%      12.00000   1.910406       2022.0  -0.537945      2.742972
# 50%      24.00000   3.044061       2022.0   0.900000      4.911191
# 75%      36.00000   5.255459       2022.0   3.200000      6.219317
# max      48.00000   8.992508       2022.0  30.729931     18.899111
#
#        Components of aggregate demand  Production    Households  Government  \
# count                       49.000000   49.000000     49.000000   49.000000
# mean                         2.703359    3.864555  29327.007927   41.664625
# std                          1.825172    2.155936   9718.568560    8.301072
# ...

# %% [markdown]
# ### Analyse des Indicateurs Économiques et Financiers
# #### Description du Projet
# Ce projet vise à analyser les caractéristiques économiques et financières des pays afin de :
#
#  * Identifier les regroupements entre les pays.
#  * Comprendre les facteurs discriminants des classifications économiques.
#  * Modéliser l’impact des variables clés sur le PIB.
#  * Comparer les niveaux de dépenses entre différents groupes économiques.
#
# **Problématique:**
# Comment les caractéristiques économiques et financières des pays peuvent-elles être analysées et modélisées pour comprendre leurs regroupements, identifier les facteurs discriminants entre classifications économiques, évaluer leurs impacts sur le PIB, et comparer les niveaux de dépenses entre différents groupes de pays ?
#
# **Méthodologies Employées:**
# * Analyse en Composantes Principales (ACP) et Clustering
#
#   * Réduction de la dimensionnalité pour extraire les axes principaux expliquant la majorité des variations des données.
#   * Regroupement des pays en clusters homogènes pour révéler des similitudes et différences.
# * Analyse Factorielle Discriminante (AFD)
#
#    * Identification des indicateurs économiques différenciant les classifications des pays (émergents, en  développement, développés).
# * Régression Linéaire et Régression Ridge
#
#    Modélisation de la relation entre la production et le PIB pour comprendre leur interdépendance.
#    Utilisation de la régularisation Ridge pour intégrer plusieurs variables (revenu, dépenses, etc.) tout en évitant le surajustement.
# * Analyse de Variance (ANOVA)
#
#   * Comparaison des niveaux de dépenses (gouvernementales, ménages, entreprises) entre les groupes de pays.
